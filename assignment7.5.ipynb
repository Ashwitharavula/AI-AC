# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwitharavula/AI-AC/blob/main/assignment7.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_item(item, items=[]):
    items.append(item)
    return items
print(add_item(1))
print(add_item(2))
# Out:
# [1]
# [1, 2]

# %%
def check_sum():
    return (0.1 + 0.2) == 0.3
print(check_sum())
# Out:
# False

# %%
def countdown(n):
    if n <= 0: # Base case to stop the recursion
        return
    print(n)
    return countdown(n-1)
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def get_value():
    data = {"a": 1, "b": 2}
    return data.get("c", None) # Safely try to get 'c', return None if not found
print(get_value())
# Out:
# None

# %%
def loop_example():
    i = 0
    while i < 5:
        print(i)

# %%
a, b, c = (1, 2, 3)

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
def func():
    x = 5
    y = 10
    return x+y
